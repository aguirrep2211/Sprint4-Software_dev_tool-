# %%
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt
import os
import pandas as pd
import plotly.express as px
import nbformat as nbf

# %%
vehicles_df = pd.read_csv('/home/aguirre_p/tripleten/sprint4/Sprint4-Software_dev_tool-/vehicles_us.csv')

# %%
vehicles_df
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
# ...

# %%
# Generate visualizations
fig_price_hist = px.histogram(vehicles_df, x="price", nbins=100, title="Distribución de Precios")
fig_odometer_hist = px.histogram(vehicles_df, x="odometer", nbins=100, title="Distribución del Kilometraje")
fig_price_model_year = px.scatter(vehicles_df, x="model_year", y="price", title="Precio vs Año del Modelo", opacity=0.5)
fig_price_odometer = px.scatter(vehicles_df, x="odometer", y="price", title="Precio vs Kilometraje", opacity=0.5)

# %%
# Crear directorio para guardar la notebook
/home/aguirre_p/tripleten/sprint4/Sprint4-Software_dev_tool-/notebooksnotebook_dir = ""
os.makedirs(notebook_dir, exist_ok=True)

# %%
# Save the notebook with visualizations
notebook_code = f"""
import pandas as pd
import plotly.express as px

# Cargar datos
df = pd.read_csv("../vehicles_us.csv")

# Histograma del precio
fig_price_hist = px.histogram(df, x="price", nbins=100, title="Distribución de Precios")
fig_price_hist.show()

# Histograma del kilometraje
fig_odometer_hist = px.histogram(df, x="odometer", nbins=100, title="Distribución del Kilometraje")
fig_odometer_hist.show()

# Scatterplot: precio vs año del modelo
fig_price_model_year = px.scatter(df, x="model_year", y="price", title="Precio vs Año del Modelo", opacity=0.5)
fig_price_model_year.show()

# Scatterplot: precio vs kilometraje
fig_price_odometer = px.scatter(df, x="odometer", y="price", title="Precio vs Kilometraje", opacity=0.5)
fig_price_odometer.show()
"""

notebook_path = f"{notebook_dir}/EDA.ipynb"

# %%
# Crear el notebook
nb = nbf.v4.new_notebook()
nb['cells'] = [nbf.v4.new_code_cell(notebook_code)]

# %%
# Guardar el archivo
notebook_path = os.path.join(notebook_dir, "EDA.ipynb")
with open(notebook_path, 'w') as f:
    nbf.write(nb, f)

# %%
import streamlit as st

# Encabezado principal
st.header("Exploración de Datos de Vehículos en EE.UU.")

# Histograma del precio
st.subheader("Distribución de Precios")
st.plotly_chart(px.histogram(vehicles_df, x="price", nbins=100, title="Distribución de Precios"))

# Scatterplot: precio vs kilometraje
st.subheader("Precio vs Kilometraje")
st.plotly_chart(px.scatter(vehicles_df, x="odometer", y="price", title="Precio vs Kilometraje", opacity=0.5))

# Checkbox para mostrar un histograma alternativo por año del modelo
if st.checkbox("Mostrar histograma por año del modelo"):
    st.subheader("Distribución de Año del Modelo")
    st.plotly_chart(px.histogram(vehicles_df, x="model_year", nbins=40, title="Distribución por Año del Modelo"))
# Out:
# 2025-04-18 12:55:05.731 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 12:55:05.822
# ...
#   command:
#
#     streamlit run /home/aguirre_p/anaconda3/envs/sprint4/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-04-18 12:55:05.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 12:55:05.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 12:55:05.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 12:55:05.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-18 12:55:05.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
